# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Helper functions

# Make Quick Graph
def plot_graph(x, y, title="", xlabel="", ylabel=""):
    plt.figure(figsize=(6, 4))
    plt.plot(x, y, linestyle="-")
    
    plt.title(title)
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.show()

# %%
# import prices.txt data
data_path = 'prices.txt'
df = pd.read_csv(data_path, sep=' ')

# %%
print(f"Number of features: {len(df.columns)}")
print(f"Number of days: {df.shape[0]}")
# Out:
# Number of features: 51
# Number of days: 500

# %%
df
# Out:
#        ALGO    AENO    LSST    SRNA   ELLT   AMRP   OTCS   HETT   HUXZ   DUCT  \
# 0    100.00  116.51  113.55  134.23  64.12  25.05  14.68  59.24  83.62  19.71
# 1     98.49  112.94  114.53  133.21  62.74  23.96  14.55  58.28  79.94  19.22
# 2     97.83  112.70  112.17  132.80  61.61  23.30  14.69  57.97  81.20  19.22
# 3     98.02  112.26  116.09  133.16  63.55  23.47  14.43  57.02  81.82  19.39
# 4     99.13  113.59  119.58  137.20  63.64  23.61  14.61  58.78  83.01  19.91
# ..      ...     ...     ...     ...    ...    ...    ...    ...    ...    ...
# 495   84.85   60.13   88.97   74.82  75.23  16.72  32.67  53.61  44.78  11.00
# 496   85.60   61.91   86.92   75.48  75.79  17.59  32.11  54.62  45.34  11.24
# 497   86.31   62.52   86.26   77.33  79.75  18.25  32.28  55.92  46.35  11.44
# 498   87.14   62.30   87.59   77.29  81.38  19.29  32.40  56.58  46.34  11.76
# 499   87.12   62.08   86.62   76.63  80.87  18.81  31.49  56.35  44.79  11.83
#
#      ...   BLBT   BENI   ITPA   HTRK   NGTE   ILVX   FCSG   FARS   MHRM   EAFC
# 0    ...  52.23  32.37  18.82  10.86  52.65  32.58  27.46  66.43  22.41  45.08
# 1    ...  52.73  32.25  18.41  10.77  49.71  31.66  26.47  64.66  22.10  44.28
# 2    ...  53.23  32.23  18.22  10.69  50.53  30.84  25.28  64.19  20.87  45.30
# 3    ...  52.67  32.20  18.22  10.28  51.64  30.95  24.60  62.80  20.95  46.32
# 4    ...  53.59  32.33  18.25  10.50  53.57  31.49  25.66  63.94  20.72  45.56
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 495  ...  33.90  25.50  20.61  11.14  33.73  40.78  32.53  32.28   8.41  17.11
# 496  ...  34.12  25.51  20.88  11.19  34.47  40.97  34.51  32.51   8.52  17.65
# 497  ...  34.50  25.75  21.72  11.16  34.94  41.89  35.03  33.17   8.67  17.58
# 498  ...  34.80  25.99  22.16  11.26  34.99  41.43  36.29  33.52   9.00  17.93
# 499  ...  34.95  25.95  22.63  11.14  35.54  41.16  36.83  34.27   9.14  17.83
#
# [500 rows x 51 columns]

# %% [markdown]
# # EDA

# %%
# Small plot
y1 = df['ALGO']
y2 = df['AENO']
x = np.arange(0, df.shape[0])

plt.figure(figsize=(6, 4))
plt.plot(x, y1, label="ALGO", linestyle="-")
plt.plot(x, y2, label="AENO", linestyle="-")

plt.title(r"Asset Pricing")
plt.ylabel("Prices")
plt.xlabel("Days")
plt.legend(loc=0, fontsize='xx-small')
plt.show()

# %%
# Large Plot
asset_list = df.columns

plt.figure(figsize=(10, 10))

for asset in asset_list:
    plt.plot(x, df[asset], label=asset, linestyle="-")

plt.title(r"Asset Pricing")
plt.ylabel("Prices")
plt.xlabel("Days")
plt.legend(loc=0, fontsize='xx-small')
plt.show()

# %%
df
# Out:
#        ALGO    AENO    LSST    SRNA   ELLT   AMRP   OTCS   HETT   HUXZ   DUCT  \
# 0    100.00  116.51  113.55  134.23  64.12  25.05  14.68  59.24  83.62  19.71
# 1     98.49  112.94  114.53  133.21  62.74  23.96  14.55  58.28  79.94  19.22
# 2     97.83  112.70  112.17  132.80  61.61  23.30  14.69  57.97  81.20  19.22
# 3     98.02  112.26  116.09  133.16  63.55  23.47  14.43  57.02  81.82  19.39
# 4     99.13  113.59  119.58  137.20  63.64  23.61  14.61  58.78  83.01  19.91
# ..      ...     ...     ...     ...    ...    ...    ...    ...    ...    ...
# 495   84.85   60.13   88.97   74.82  75.23  16.72  32.67  53.61  44.78  11.00
# 496   85.60   61.91   86.92   75.48  75.79  17.59  32.11  54.62  45.34  11.24
# 497   86.31   62.52   86.26   77.33  79.75  18.25  32.28  55.92  46.35  11.44
# 498   87.14   62.30   87.59   77.29  81.38  19.29  32.40  56.58  46.34  11.76
# 499   87.12   62.08   86.62   76.63  80.87  18.81  31.49  56.35  44.79  11.83
#
#      ...   BLBT   BENI   ITPA   HTRK   NGTE   ILVX   FCSG   FARS   MHRM   EAFC
# 0    ...  52.23  32.37  18.82  10.86  52.65  32.58  27.46  66.43  22.41  45.08
# 1    ...  52.73  32.25  18.41  10.77  49.71  31.66  26.47  64.66  22.10  44.28
# 2    ...  53.23  32.23  18.22  10.69  50.53  30.84  25.28  64.19  20.87  45.30
# 3    ...  52.67  32.20  18.22  10.28  51.64  30.95  24.60  62.80  20.95  46.32
# 4    ...  53.59  32.33  18.25  10.50  53.57  31.49  25.66  63.94  20.72  45.56
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 495  ...  33.90  25.50  20.61  11.14  33.73  40.78  32.53  32.28   8.41  17.11
# 496  ...  34.12  25.51  20.88  11.19  34.47  40.97  34.51  32.51   8.52  17.65
# 497  ...  34.50  25.75  21.72  11.16  34.94  41.89  35.03  33.17   8.67  17.58
# 498  ...  34.80  25.99  22.16  11.26  34.99  41.43  36.29  33.52   9.00  17.93
# 499  ...  34.95  25.95  22.63  11.14  35.54  41.16  36.83  34.27   9.14  17.83
#
# [500 rows x 51 columns]

# %% [markdown]
# ### Cross Correlation

# %%
asset_list
# Out:
# Index(['ALGO', 'AENO', 'LSST', 'SRNA', 'ELLT', 'AMRP', 'OTCS', 'HETT', 'HUXZ',
#        'DUCT', 'SMAH', 'NPCK', 'MSDP', 'EORC', 'CUBO', 'HRET', 'ANSO', 'DIHO',
#        'RTTH', 'SPLZ', 'NWIG', 'MMBT', 'MDGI', 'AGVF', 'RRES', 'CTGI', 'ALUT',
#        'ACAC', 'SRTX', 'GARI', 'RCRI', 'ACIX', 'CCNS', 'MTNS', 'IHOZ', 'NAYO',
#        'FWWG', 'EELT', 'HRND', 'AETS', 'ULXY', 'BLBT', 'BENI', 'ITPA', 'HTRK',
#        'NGTE', 'ILVX', 'FCSG', 'FARS', 'MHRM', 'EAFC'],
#       dtype='str')

# %%
for asset in asset_list:
    asset_1 = asset_list[0]
    asset_2 = asset
    
    t1 = df[asset_1]
    t2 = df[asset_2]
    
    t1_norm = (t1 - t1.mean()) / t1.std()
    t2_norm = (t2 - t2.mean()) / t2.std()
    
    lags = np.arange(-100, 101)
    cross_corr = [t1_norm.corr(t2_norm.shift(lag)) for lag in lags]
    
    print(f"['{asset_1}'], ['{asset_2}'], Max corr: {max(cross_corr)}, lags: {lags[np.argmax(cross_corr)]}")
# Out:
# ['ALGO'], ['ALGO'], Max corr: 1.0, lags: 0
# ['ALGO'], ['AENO'], Max corr: 0.8277147884022338, lags: 93
# ['ALGO'], ['LSST'], Max corr: 0.11634530421902235, lags: -100
# ['ALGO'], ['SRNA'], Max corr: 0.8097626357060991, lags: 0
# ['ALGO'], ['ELLT'], Max corr: 0.660622229356971, lags: -10
# ['ALGO'], ['AMRP'], Max corr: 0.4943360252871294, lags: 100
# ['ALGO'], ['OTCS'], Max corr: 0.6720572824244817, lags: -100
# ['ALGO'], ['HETT'], Max corr: 0.37166665372029417, lags: -100
# ['ALGO'], ['HUXZ'], Max corr: 0.6711364591070892, lags: 0
# ['ALGO'], ['DUCT'], Max corr: 0.8127908520609314, lags: 70
# ['ALGO'], ['SMAH'], Max corr: 0.5600339370790173, lags: -69
# ['ALGO'], ['NPCK'], Max corr: 0.5044710587087824, lags: 100
# ['ALGO'], ['MSDP'], Max corr: 0.3158854370764356, lags: 0
# ['ALGO'], ['EORC'], Max corr: 0.8863783348156977, lags: 0
# ['ALGO'], ['CUBO'], Max corr: 0.5382943084792221, lags: -100
# ['ALGO'], ['HRET'], Max corr: 0.7526971144404038, lags: 0
# ['ALGO'], ['ANSO'], Max corr: 0.6835864168591527, lags: -98
# ['ALGO'], ['DIHO'], Max corr: 0.5413877297332093, lags: 0
# ['ALGO'], ['RTTH'], Max corr: 0.34161696083990845, lags: 0
# ['ALGO'], ['SPLZ'], Max corr: 0.6119755478433682, lags: 0
# ['ALGO'], ['NWIG'], Max corr: 0.8283045721363831, lags: 93
# ['ALGO'], ['MMBT'], Max corr: 0.18712495446961572, lags: -10
# ['ALGO'], ['MDGI'], Max corr: 0.5999011796584909, lags: 0
# ['ALGO'], ['AGVF'], Max corr: 0.6200839523801952, lags: 11
# ['ALGO'], ['RRES'], Max corr: 0.3732370695387201, lags: -100
# ['ALGO'], ['CTGI'], Max corr: 0.4700647714589482, lags: -94
# ['ALGO'], ['ALUT'], Max corr: 0.2540460209930258, lags: 0
# ['ALGO'], ['ACAC'], Max corr: 0.679879174606656, lags: 0
# ['ALGO'], ['SRTX'], Max corr: 0.6567240521297981, lags: 0
# ['ALGO'], ['GARI'], Max corr: 0.6294284088570437, lags: 99
# ['ALGO'], ['RCRI'], Max corr: 0.31363459525227827, lags: 100
# ['ALGO'], ['ACIX'], Max corr: 0.6471913363044989, lags: -62
# ['ALGO'], ['CCNS'], Max corr: 0.3808842515351932, lags: 0
# ['ALGO'], ['MTNS'], Max corr: 0.26057366370339263, lags: -100
# ['ALGO'], ['IHOZ'], Max corr: 0.5873918931533819, lags: 100
# ['ALGO'], ['NAYO'], Max corr: 0.48386636349159223, lags: 0
# ['ALGO'], ['FWWG'], Max corr: 0.6688340535005008, lags: 92
# ['ALGO'], ['EELT'], Max corr: 0.45725779660460464, lags: -37
# ['ALGO'], ['HRND'], Max corr: 0.8788653881503258, lags: 80
# ['ALGO'], ['AETS'], Max corr: 0.5761006932268997, lags: 0
# ['ALGO'], ['ULXY'], Max corr: 0.5150366623732886, lags: -99
# ['ALGO'], ['BLBT'], Max corr: 0.5546174187328852, lags: 11
# ['ALGO'], ['BENI'], Max corr: 0.09856255906696472, lags: 0
# ['ALGO'], ['ITPA'], Max corr: 0.69729658841966, lags: -63
# ['ALGO'], ['HTRK'], Max corr: 0.7333271687657, lags: 0
# ['ALGO'], ['NGTE'], Max corr: 0.8898059956707559, lags: 0
# ['ALGO'], ['ILVX'], Max corr: 0.5779207569869373, lags: -69
# ['ALGO'], ['FCSG'], Max corr: 0.46063229654531884, lags: -100
# ['ALGO'], ['FARS'], Max corr: 0.4158505054860899, lags: 100
# ['ALGO'], ['MHRM'], Max corr: 0.6455837691539044, lags: 77
# ['ALGO'], ['EAFC'], Max corr: 0.6346437296428296, lags: 67

# %%
asset_1 = asset_list[0]
asset_2 = 'FARS'

t1 = df[asset_1]
t2 = df[asset_2]

t1_norm = (t1 - t1.mean()) / t1.std()
t2_norm = (t2 - t2.mean()) / t2.std()

lags = np.arange(-100, 101)
cross_corr = [t1_norm.corr(t2_norm.shift(lag)) for lag in lags]

print(f"['{asset_1}'], ['{asset_2}'], Max corr: {max(cross_corr)}, lags: {lags[np.argmax(cross_corr)]}")
# Out:
# ['ALGO'], ['FARS'], Max corr: 0.4158505054860899, lags: 100

# %%
plot_graph(lags, cross_corr)

# %%
max(cross_corr)
# Out:
# np.float64(0.8097626357060991)

# %%
np.argmax(cross_corr)
# Out:
# np.int64(100)

# %%
cross_corr[100]
# Out:
# np.float64(0.8097626357060991)

# %%
cross_corr[101]
# Out:
# np.float64(0.8071548025367795)

# %%
cross_corr[99]
# Out:
# np.float64(0.8055593876708763)

# %%
# Small plot
y = t1
x = np.arange(0, t1.shape[0])

plt.figure(figsize=(6, 4))
plt.plot(x, y, label="ALGO", linestyle="-")

plt.title(r"Asset Pricing")
plt.ylabel("Prices")
plt.xlabel("Days")
plt.legend(loc=0, fontsize='xx-small')
plt.show()

# %%
# Small plot
y = t1_norm
x = np.arange(0, t1.shape[0])

plot_graph(x, y)

# %%
for asset in asset_list:
    statsmodels_correlation = sm.OLS(df[asset_list[0]], df[asset]).fit().rsquared
    print(f'Statsmodels Correlation [{asset}]:', statsmodels_correlation)
# Out:
# Statsmodels Correlation [ALGO]: 1.0
# Statsmodels Correlation [AENO]: 0.9561835023819267
# Statsmodels Correlation [LSST]: 0.9756891855355978
# Statsmodels Correlation [SRNA]: 0.9781245350143275
# Statsmodels Correlation [ELLT]: 0.9816429350215996
# Statsmodels Correlation [AMRP]: 0.9551461819452036
# Statsmodels Correlation [OTCS]: 0.9289555961975255
# Statsmodels Correlation [HETT]: 0.987050633728418
# Statsmodels Correlation [HUXZ]: 0.9762490863157539
# Statsmodels Correlation [DUCT]: 0.9656355983728385
# Statsmodels Correlation [SMAH]: 0.9601744257078956
# Statsmodels Correlation [NPCK]: 0.935252424440037
# Statsmodels Correlation [MSDP]: 0.9701181323578046
# Statsmodels Correlation [EORC]: 0.9693315777446339
# Statsmodels Correlation [CUBO]: 0.965834372074885
# Statsmodels Correlation [HRET]: 0.9891668674970081
# Statsmodels Correlation [ANSO]: 0.9648103819299847
# Statsmodels Correlation [DIHO]: 0.9927400348983934
# Statsmodels Correlation [RTTH]: 0.9819979487747509
# Statsmodels Correlation [SPLZ]: 0.9793483415261647
# Statsmodels Correlation [NWIG]: 0.9553450165189099
# Statsmodels Correlation [MMBT]: 0.926150464368712
# Statsmodels Correlation [MDGI]: 0.9807653429671542
# Statsmodels Correlation [AGVF]: 0.9742681623829962
# Statsmodels Correlation [RRES]: 0.9469526218152929
# Statsmodels Correlation [CTGI]: 0.9773375605857411
# Statsmodels Correlation [ALUT]: 0.9818983769582167
# Statsmodels Correlation [ACAC]: 0.9794940003808915
# Statsmodels Correlation [SRTX]: 0.9866892894296707
# Statsmodels Correlation [GARI]: 0.9695279656881638
# Statsmodels Correlation [RCRI]: 0.9751558130668049
# Statsmodels Correlation [ACIX]: 0.9909799187335688
# Statsmodels Correlation [CCNS]: 0.9817263611385799
# Statsmodels Correlation [MTNS]: 0.992655869318641
# Statsmodels Correlation [IHOZ]: 0.9879735845423002
# Statsmodels Correlation [NAYO]: 0.9903367685128853
# Statsmodels Correlation [FWWG]: 0.9918607578261176
# Statsmodels Correlation [EELT]: 0.9812409456617421
# Statsmodels Correlation [HRND]: 0.9233657118022432
# Statsmodels Correlation [AETS]: 0.974675979616621
# Statsmodels Correlation [ULXY]: 0.9867163957664191
# Statsmodels Correlation [BLBT]: 0.9903735116795834
# Statsmodels Correlation [BENI]: 0.9923743661518885
# Statsmodels Correlation [ITPA]: 0.9912017705703143
# Statsmodels Correlation [HTRK]: 0.9964199426536795
# Statsmodels Correlation [NGTE]: 0.9710468667450607
# Statsmodels Correlation [ILVX]: 0.9618479410522527
# Statsmodels Correlation [FCSG]: 0.971327966520451
# Statsmodels Correlation [FARS]: 0.9577494648367199
# Statsmodels Correlation [MHRM]: 0.9746997388677759
# Statsmodels Correlation [EAFC]: 0.9705236137366074

# %%
from statsmodels.tsa.stattools import adfuller
price_series = df['ALGO']




result = adfuller(price_series)
print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")
# p-value > 0.05 → fail to reject unit root → non-stationary, needs differencing
# Out:
# ADF Statistic: -1.0869391985053634
# p-value: 0.7202521987113772

# %%
import matplotlib.pyplot as plt

series = df['ALGO']

rolling_mean = series.rolling(window=10).mean()
rolling_std = series.rolling(window=10).std()

plt.plot(series, label='Original')
plt.plot(rolling_mean, label='Rolling Mean')
#plt.plot(rolling_std, label='Rolling Std')
plt.legend()
plt.title('Rolling Statistics')
plt.show()

# %%
plt.plot(rolling_std, label='Rolling Std')
plt.legend()
plt.title('Rolling Statistics')
plt.show()

# %%
# Simple returns
returns = price_series.pct_change().dropna()

# Or log returns (usually preferred - more symmetric, additive over time)
log_returns = np.log(price_series / price_series.shift(1)).dropna()

# %%
result = adfuller(log_returns)
print(f"p-value: {result[1]}")  # should now be well below 0.05
# Out:
# p-value: 1.150654520078156e-29

# %%
rolling_vol = log_returns.rolling(window=20).std()
standardized_returns = log_returns / rolling_vol
standardized_returns = standardized_returns.dropna()

# %%
from statsmodels.tsa.stattools import ccf

# Align the two return series on the same dates first
cross_corr = ccf(log_returns_A, log_returns_B, adjusted=False)

# Or look at specific lags manually
import matplotlib.pyplot as plt
lags = range(-20, 21)
ccf_vals = [log_returns_A.corr(log_returns_B.shift(lag)) for lag in lags]

plt.stem(lags, ccf_vals)
plt.axhline(0, color='black', linewidth=0.5)
plt.xlabel("Lag")
plt.ylabel("Cross-correlation")
plt.title("Cross-Correlation Function")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 4
#       1 from statsmodels.tsa.stattools import ccf
#       3 # Align the two return series on the same dates first
# ----> 4 cross_corr = ccf(log_returns_A, log_returns_B, adjusted=False)
#       6 # Or look at specific lags manually
#       7 import matplotlib.pyplot as plt
#
# NameError: name 'log_returns_A' is not defined

# %%
test_df = pd.DataFrame(data)

# %%
test_df
# Out:
#      Days   Price
# 0       0  100.00
# 1       1   98.49
# 2       2   97.83
# 3       3   98.02
# 4       4   99.13
# ..    ...     ...
# 495   495   84.85
# 496   496   85.60
# 497   497   86.31
# 498   498   87.14
# 499   499   87.12
#
# [500 rows x 2 columns]

# %% [markdown]
# ### Kendall Tau

# %%
import scipy.stats as stats
for asset in asset_list:
    tau, p_value = stats.kendalltau(df[asset_list[0]], df[asset])
    print(f"Tau: {tau}, P-Value: {p_value}")
# Out:
# Tau: 1.0, P-Value: 1.0189484393240909e-244
# Tau: 0.34111411646405576, P-Value: 4.2937214618079935e-30
# Tau: -0.1551305184850087, P-Value: 2.1855746281785038e-07
# Tau: 0.5700539707042842, P-Value: 6.879765045949302e-81
# Tau: 0.4935871007322494, P-Value: 4.1642147881442e-61
# Tau: -0.11198550059953509, P-Value: 0.00018380079494721035
# Tau: 0.06153735111896428, P-Value: 0.03979985245553012
# Tau: -0.05567049997257801, P-Value: 0.06289081335926056
# Tau: 0.38544778401589624, P-Value: 5.904647248586547e-38
# Tau: 0.4278294958626558, P-Value: 2.486861058978894e-46
# Tau: 0.23288599526485618, P-Value: 7.199750833756796e-15
# Tau: 0.19880945139063694, P-Value: 3.1458738553046556e-11
# Tau: 0.21951131576391142, P-Value: 2.251289593499214e-13
# Tau: 0.6836845988735564, P-Value: 1.7976107066112542e-115
# Tau: -0.2747978403540624, P-Value: 4.2244255600186595e-20
# Tau: 0.6220839317698912, P-Value: 6.067907901345174e-96
# Tau: 0.06732346139071167, P-Value: 0.024495716124556706
# Tau: 0.38306025917571473, P-Value: 2.0176321701262167e-37
# Tau: 0.24363719488784502, P-Value: 3.9718020871355634e-16
# Tau: 0.38818345702631185, P-Value: 1.8064353511244715e-38
# Tau: 0.3594529959720007, P-Value: 3.111679795371757e-33
# Tau: 0.2115724656048787, P-Value: 1.5512350658106203e-12
# Tau: 0.5126065005597134, P-Value: 9.028465731338369e-66
# Tau: 0.26502121138560625, P-Value: 8.364959469219499e-19
# Tau: -0.09670447769543936, P-Value: 0.0012337732852284308
# Tau: 0.2945232967786116, P-Value: 7.494643575860582e-23
# Tau: 0.10151267887529729, P-Value: 0.0007006424194295731
# Tau: 0.38121356699763154, P-Value: 3.667144755008166e-37
# Tau: 0.3113491648123335, P-Value: 2.379070363709402e-25
# Tau: 0.13085702550545766, P-Value: 1.2412832752165098e-05
# Tau: 0.0879488362408319, P-Value: 0.003299357420130663
# Tau: 0.35291243942136996, P-Value: 4.7272422230103917e-32
# Tau: 0.18121288102225833, P-Value: 1.4281936778544793e-09
# Tau: 0.12835521511849712, P-Value: 1.831529809277583e-05
# Tau: 0.36528014879720894, P-Value: 2.905561871384788e-34
# Tau: 0.3075349820482589, P-Value: 9.30502027446035e-25
# Tau: 0.3333507269173833, P-Value: 8.587054971981272e-29
# Tau: 0.3324084626385921, P-Value: 1.1705154583088763e-28
# Tau: 0.41821484584141855, P-Value: 2.320146514324857e-44
# Tau: 0.43182638426569964, P-Value: 3.5315762274168805e-47
# Tau: 0.007931956817666785, P-Value: 0.7910233235145101
# Tau: 0.31670383135572905, P-Value: 3.7109702640759243e-26
# Tau: 0.06221060887529715, P-Value: 0.03780134672818231
# Tau: 0.3369412985825766, P-Value: 2.277608094705103e-29
# Tau: 0.5622600020324258, P-Value: 1.5064946600205434e-78
# Tau: 0.6910869684375747, P-Value: 5.749662579835247e-118
# Tau: 0.22349836886987137, P-Value: 8.259545296902667e-14
# Tau: 0.014589290299137978, P-Value: 0.6260007727059419
# Tau: 0.04875075685346902, P-Value: 0.10336799229217171
# Tau: 0.2772585592594915, P-Value: 2.0507545042690978e-20
# Tau: 0.34310576474482085, P-Value: 2.040772249688126e-30

# %% [markdown]
# # Submission testing

# %%
#!/usr/bin/env python
"""Algothon 2026 evaluation script.

Participants: write getMyPosition(prcSoFar) in teamName.py and update the imports below
"""

import numpy as np
import pandas as pd
from AlphaLeak import getMyPosition as getPosition

nInst = 0
nt = 0

pricesFile = "./prices.txt"
numTestDays = 250

# parameter for scoring function
scoreDefaultParam = 1.0

# commission rates (0.0001 = 1bp)
# SPECIAL rate for instrument 0
defaultCommRate = 0.0001
inst0CommRate = 0.00002

# position limits (dollars)
# SPECIAL position limit for instrument 0
defaultDlrPosLimit = 10_000
inst0DlrPosLimit = 100_000

def loadPrices(fn):
    """
    Load prices from csv file (one instrument per column) and transpose into one instrument per row
    """
    global nt, nInst
    df = pd.read_csv(fn, sep=r"\s+", header=0, index_col=None)
    nt, nInst = df.shape
    return (df.values).T


def chargeFees(dvolumes, commRate):
    """
    Total commission for one day's trades.
    """
    return np.sum(dvolumes * commRate)


def score(mu, sigma, param=scoreDefaultParam):
    """
    Final score from the daily-PnL mean & std, plus a scoring parameter.
    """
    if mu <= 0 or sigma < 1e-10:
        return mu
    sr = np.sqrt(250) * mu / sigma
    frac = sr**2 / (sr**2 + param**2)
    return mu * frac

prcAll = loadPrices(pricesFile)
print(f"Loaded {nInst} instruments for {nt} days")

# initialise the per-instrument commissions and position limits
commRate = np.full(nInst, defaultCommRate)
commRate[0] = inst0CommRate
dlrPosLimit = np.full(nInst, defaultDlrPosLimit)
dlrPosLimit[0] = inst0DlrPosLimit

def calcPL(prcHist, numTestDays):
    """
    Function to loop over days and calculate/store PnLs
    """
    
    # initial values
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    value = 0
    comm = 0
    
    todayPLL = []
    _, nt = prcHist.shape
    # start day is the first day to run getPosition() on
    # e.g. startDay=500 if last 250 of 750 days used as test days
    startDay = nt - numTestDays
    
    for t in range(startDay, nt + 1):
        # price history up to and including t, e.g. if t=500, gets first 500 days
        prcHistSoFar = prcHist[:, :t]
        curPrices = prcHistSoFar[:, -1]

        # trading loop, do not do it on the very last day of the test
        if t < nt:
            # get new positions
            newPosOrig = getPosition(prcHistSoFar)

            # clip to position limits, and enforce integer shares
            posLimits = (dlrPosLimit / curPrices).astype(int)
            newPos = np.clip(newPosOrig, -posLimits, posLimits).astype(int)
        else:
            # the final day is only used as 'mark' of final PnL
            newPos = np.array(curPos)

        # change in positions
        deltaPos = newPos - curPos
        
        cash -= curPrices.dot(deltaPos) + comm

        # calculate commissions
        dvolumes = curPrices * np.abs(deltaPos)
        dvolume = np.sum(dvolumes)
        totDVolume += dvolume
        comm = chargeFees(dvolumes, commRate)
            
        curPos = np.array(newPos)
        posValue = curPos.dot(curPrices)
        # PnL is the daily change in portfolio value (cash plus positions)
        todayPL = cash + posValue - value
        
        value = cash + posValue

        # calculate return (portfolio value over total dollar volume)
        ret = 0.0
        if totDVolume > 0:
            ret = value / totDVolume

        # only score for test days
        if t > startDay:
            print(
                f"Day {t} value: {value:.2f} todayPL: ${todayPL:.2f} $-traded: {totDVolume:.0f} return: {ret:.5f}"
            )
            todayPLL.append(todayPL)
            
    pll = np.array(todayPLL)
    plmu, plstd = (np.mean(pll), np.std(pll))

    # calculate annualised Sharpe
    annSharpe = 0.0
    if plstd > 0:
        annSharpe = np.sqrt(250) * plmu / plstd
        
    return (plmu, ret, plstd, annSharpe, totDVolume)

meanpl, ret, plstd, sharpe, dvol = calcPL(prcAll, numTestDays)
scoreVal = score(meanpl, plstd, scoreDefaultParam)
print("=====")
print(f"mean(PL): {meanpl:.1f}")
print(f"return: {ret:.5f}")
print(f"StdDev(PL): {plstd:.2f}")
print(f"annSharpe(PL): {sharpe:.2f}")
print(f"totDvolume: {dvol:.0f}")
print(f"Score: {scoreVal:.2f}")
# Out:
# Loaded 51 instruments for 500 days
# Day 251 value: 40.24 todayPL: $40.24 $-traded: 51415 return: 0.00078
# Day 252 value: 63.05 todayPL: $22.82 $-traded: 78447 return: 0.00080
# Day 253 value: -458.01 todayPL: $-521.06 $-traded: 107577 return: -0.00426
# Day 254 value: -649.35 todayPL: $-191.34 $-traded: 136392 return: -0.00476
# Day 255 value: -729.44 todayPL: $-80.10 $-traded: 162273 return: -0.00450
# Day 256 value: -528.83 todayPL: $200.62 $-traded: 189149 return: -0.00280
# Day 476 value: 5169.49 todayPL: $2157.75 $-traded: 5459218 return: 0.00095
# Day 477 value: 6985.59 todayPL: $1816.09 $-traded: 5480193 return: 0.00127
# Day 478 value: 4040.63 todayPL: $-2944.95 $-traded: 5501139 return: 0.00073
# Day 479 value: 6102.75 todayPL: $2062.12 $-traded: 5521823 return: 0.00111
# Day 480 value: 7141.60 todayPL: $1038.85 $-traded: 5541854 return: 0.00129
# Day 481 value: 5782.44 todayPL: $-1359.16 $-traded: 5560252 return: 0.00104
# Day 482 value: 3259.69 todayPL: $-2522.75 $-traded: 5582060 return: 0.00058
# Day 483 value: 2459.92 todayPL: $-799.77 $-traded: 5602315 return: 0.00044
# Day 484 value: 2209.45 todayPL: $-250.47 $-traded: 5621732 return: 0.00039
# Day 485 value: -2240.16 todayPL: $-4449.61 $-traded: 5641503 return: -0.00040
# Day 486 value: 572.04 todayPL: $2812.20 $-traded: 5663306 return: 0.00010
# Day 487 value: 2193.48 todayPL: $1621.44 $-traded: 5682237 return: 0.00039
# Day 488 value: 359.95 todayPL: $-1833.53 $-traded: 5703560 return: 0.00006
# Day 489 value: -830.70 todayPL: $-1190.64 $-traded: 5723381 return: -0.00015
# Day 490 value: 3154.68 todayPL: $3985.38 $-traded: 5744327 return: 0.00055
# Day 491 value: 3583.17 todayPL: $428.49 $-traded: 5764692 return: 0.00062
# Day 492 value: 6402.45 todayPL: $2819.28 $-traded: 5784312 return: 0.00111
# Day 493 value: 6307.63 todayPL: $-94.82 $-traded: 5802141 return: 0.00109
# Day 494 value: 9652.33 todayPL: $3344.69 $-traded: 5822414 return: 0.00166
# Day 495 value: 12719.16 todayPL: $3066.84 $-traded: 5842917 return: 0.00218
# Day 496 value: 12877.74 todayPL: $158.58 $-traded: 5860966 return: 0.00220
# Day 497 value: 8135.68 todayPL: $-4742.05 $-traded: 5879753 return: 0.00138
# Day 498 value: 5010.53 todayPL: $-3125.16 $-traded: 5899227 return: 0.00085
# Day 499 value: 2564.17 todayPL: $-2446.36 $-traded: 5919621 return: 0.00043
# Day 500 value: 2589.92 todayPL: $25.75 $-traded: 5919621 return: 0.00044
# =====
# mean(PL): 10.4
# return: 0.00044
# StdDev(PL): 1640.20
# annSharpe(PL): 0.10
# totDvolume: 5919621
# Score: 0.10

# %%
_, n = prcAll.shape

# %%
numTestDays
# Out:
# 250

# %%
for t in range(250, 260):
    # price history up to and including t, e.g. if t=500, gets first 500 days
    prcHistSoFar = prcAll[:, :t]
    curPrices = prcHistSoFar[:, -1]

# %%
prcHistSoFar
# Out:
# array([[100.  ,  98.49,  97.83, ..., 104.63, 105.18, 105.19],
#        [116.51, 112.94, 112.7 , ...,  96.55, 100.56,  98.93],
#        [113.55, 114.53, 112.17, ...,  74.53,  77.19,  76.81],
#        ...,
#        [ 66.43,  64.66,  64.19, ...,  40.01,  39.73,  39.33],
#        [ 22.41,  22.1 ,  20.87, ...,  16.03,  16.06,  16.31],
#        [ 45.08,  44.28,  45.3 , ...,  32.  ,  32.  ,  32.14]],
#       shape=(51, 259))

# %%
prcHistSoFar[:, -1]
# Out:
# array([105.19,  98.93,  76.81, 130.66, 104.43,  17.14,  22.02,  64.33,
#         78.14,  19.01,  65.26,  10.29,  23.98,  45.41, 125.12,  62.89,
#         59.87,  12.08,  38.8 ,  83.55, 104.11, 138.57, 277.82, 105.83,
#         45.24, 128.2 ,  14.67,  73.61, 269.59,  11.43,  43.74,  18.77,
#         17.87,  17.56, 137.32,  36.79,  33.51, 121.15,  29.44,  35.23,
#         46.68,  42.97,  25.2 ,  22.88,  12.52,  72.8 ,  46.86,  29.82,
#         39.33,  16.31,  32.14])

# %%
nInst=51
currentPos = np.zeros(nInst)

def getMyPosition (prcSoFar):
    currentPos = np.ones(51)*10000
    currentPos[0] = 100000
    return currentPos

getMyPosition(prcHistSoFar)
# Out:
# array([100000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.])

# %%
prcHistSoFar.shape
# Out:
# (51, 259)

# %%
np.log(prcHistSoFar[:,-1] / prcHistSoFar[:,-2])
# Out:
# array([ 9.50705900e-05, -1.63420349e-02, -4.93507495e-03, -2.21704154e-03,
#        -4.96705578e-03,  4.67837111e-03,  2.57603941e-02, -2.04638267e-02,
#        -3.70441760e-03, -4.72317855e-03,  7.69116236e-03, -2.59007284e-02,
#         1.51263388e-02, -1.97998085e-03, -2.31509304e-03,  1.92653253e-02,
#        -2.55599701e-02, -7.42271449e-03,  2.32053171e-02,  6.24326677e-03,
#         8.10111480e-03, -5.05172121e-02,  2.00690223e-02,  3.86274846e-02,
#         3.41759879e-02,  2.22424186e-02, -4.76029461e-03, -8.92621561e-03,
#        -4.03502500e-03, -3.49345333e-03, -4.09865900e-02,  4.27122913e-03,
#        -1.55472315e-02, -1.86183093e-02, -3.12647944e-03, -4.88031076e-02,
#         5.98624954e-03,  1.87466436e-02,  1.71295727e-02,  4.88611289e-02,
#         1.33709130e-02,  8.41323028e-03, -1.26184640e-02,  1.36415757e-02,
#         2.34354160e-02, -4.30173851e-02, -1.18796476e-02,  1.01113096e-02,
#        -1.01189834e-02,  1.54467081e-02,  4.36545751e-03])

# %%
prcHistSoFar[:,-1] / prcHistSoFar[:,-2]
# Out:
# array([1.00009508, 0.98379077, 0.99507708, 0.99778541, 0.99504526,
#        1.00468933, 1.02609506, 0.97974414, 0.99630244, 0.99528796,
#        1.00772082, 0.97443182, 1.01524132, 0.99802198, 0.99768758,
#        1.0194521 , 0.97476392, 0.99260477, 1.02347666, 1.0062628 ,
#        1.00813402, 0.95073756, 1.02027176, 1.03938323, 1.0347667 ,
#        1.02249163, 0.99525102, 0.9911135 , 0.9959731 , 0.99651264,
#        0.959842  , 1.00428036, 0.984573  , 0.98155394, 0.9968784 ,
#        0.95236863, 1.0060042 , 1.01892347, 1.01727713, 1.05007452,
#        1.0134607 , 1.00844872, 0.98746082, 1.01373505, 1.02371218,
#        0.95789474, 0.98819064, 1.0101626 , 0.98993204, 1.01556663,
#        1.004375  ])

# %%
    currentPos = np.ones(51)*10000
    currentPos[0] = 100000

# %%
currentPos
# Out:
# array([100000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.,  10000.,  10000.,  10000.,  10000.,  10000.,
#         10000.,  10000.])
